# %% [markdown]
# Importar dataset y librerias

# %%
import pandas as pd
import os

#Import the dataset
dataset = dataset = os.path.join('..','Lorca_processed.csv')
                               
data = pd.read_csv(
        dataset,
        sep=";",
        low_memory=False,
)

data["datetime"] = pd.to_datetime(data["datetime"], dayfirst=True, errors="coerce") #convertimos time a datatime
data["month"] = data["datetime"].dt.month
data["day"] = data["datetime"].dt.day
data["hour"] = data["datetime"].dt.hour
data["minute"] = data["datetime"].dt.minute

data.drop(columns=["datetime"], inplace=True) #eliminamos la columna Time



data.head(10)
# Out:
#    temperature  windSpeed  solarRad  humedad  rain  Power_gen  \
# 0      10.5556    0.00000         0       57   0.0     0.0000
# 1      17.6667   17.70280       504       39   0.0     2.8780
# 2      17.6111    9.65606       626       40   0.0     5.7560
# 3      18.0556   16.09340       664       42   0.0     8.6340
# 4      17.6111    1.60934       664       38   0.0    11.5120
# 5      18.5000    4.82803       682       37   0.0     9.2096
# 6      18.6111   12.87480       680       38   0.0     6.9072
# 7      18.5556   12.87480       617       39   0.0     4.6048
# 8      18.1667    9.65606       619       37   0.0     2.3024
# 9      18.2222    4.82803       670       38   0.0     0.0000
#
#    pressure_sensor  pressure  month  day  hour  minute
# 0       170.602742    28.991      2    6     4      54
# 1       385.968892    28.960      3    5    12       9
# 2       385.426481    28.962      3    5    12      14
# 3       385.411336    28.961      3    5    12      19
# 4       385.049863    28.959      3    5    12      24
# 5       385.366369    28.932      3    5    13      24
# 6       385.503740    28.931      3    5    13      29
# 7       385.154409    28.928      3    5    13      34
# 8       385.622396    28.926      3    5    13      39
# 9       385.252950    28.923      3    5    13      44

# %% [markdown]
# Separamos las variables predictoras y la variable objetivo

# %%
#Eliminamos filas con valores NaN antes de dividir en train y test
df_clean = data.dropna(subset=['Power_gen'])
predictors = df_clean.drop(columns=['Power_gen'])
objective = df_clean['Power_gen']

# %% [markdown]
# Dividimos los datos en train y test

# %%
#Dividimos los datos en train y test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(predictors, objective, test_size=0.2, random_state=42) #20% para test

# %% [markdown]
# Calculamos los parámetros óptimos del modelo

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV

params = {'max_depth': [2, 5, 9], #profundidad maxima del arbol
          'learning_rate': [0.01, 0.1, 0.2], #tasa de aprendizaje
          'n_estimators': [50, 100, 900], #numero de arboles
          'subsample': [0.6, 0.8, 1.0]} #datos para entrenamiento de cada arbol
pruebas = XGBRegressor()
grid = GridSearchCV(pruebas, params, scoring='neg_root_mean_squared_error', cv=2, verbose=2) #calculamos el valor optimo de los parametros
grid.fit(X_train, y_train)
print(grid.best_params_)
# Out:
# Fitting 2 folds for each of 81 candidates, totalling 162 fits
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=900, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=900, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=900, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=900, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=900, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=900, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=900, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=900, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=900, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=900, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=900, subsample=1.0; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=900, subsample=1.0; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=50, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=50, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=100, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=100, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=900, subsample=0.6; total time=   1.1s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=900, subsample=0.6; total time=   2.2s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=900, subsample=0.8; total time=   3.6s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=900, subsample=0.8; total time=   2.7s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=900, subsample=1.0; total time=   3.1s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=900, subsample=1.0; total time=   2.7s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=900, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=900, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=900, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=900, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=900, subsample=1.0; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=900, subsample=1.0; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=50, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=50, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=900, subsample=0.6; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=900, subsample=0.6; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=900, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=900, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=900, subsample=1.0; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=900, subsample=1.0; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=50, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=50, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=50, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=50, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=100, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=100, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=100, subsample=1.0; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=100, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=900, subsample=0.6; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=900, subsample=0.6; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=900, subsample=0.8; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=900, subsample=0.8; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=900, subsample=1.0; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=900, subsample=1.0; total time=   0.9s
# [CV] END learning_rate=0.2, max_depth=2, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.2, max_depth=2, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.2, max_depth=2, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.2, max_depth=2, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.2, max_depth=2, n_estimators=50, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.2, max_depth=2, n_estimators=50, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.2, max_depth=2, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.2, max_depth=2, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.2, max_depth=2, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.2, max_depth=2, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.2, max_depth=2, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.2, max_depth=2, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.2, max_depth=2, n_estimators=900, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.2, max_depth=2, n_estimators=900, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.2, max_depth=2, n_estimators=900, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.2, max_depth=2, n_estimators=900, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.2, max_depth=2, n_estimators=900, subsample=1.0; total time=   0.3s
# [CV] END learning_rate=0.2, max_depth=2, n_estimators=900, subsample=1.0; total time=   0.3s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=50, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=50, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=900, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=900, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=900, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=900, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=900, subsample=1.0; total time=   0.6s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=900, subsample=1.0; total time=   0.6s
# [CV] END learning_rate=0.2, max_depth=9, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.2, max_depth=9, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.2, max_depth=9, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.2, max_depth=9, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.2, max_depth=9, n_estimators=50, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.2, max_depth=9, n_estimators=50, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.2, max_depth=9, n_estimators=100, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.2, max_depth=9, n_estimators=100, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.2, max_depth=9, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.2, max_depth=9, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.2, max_depth=9, n_estimators=100, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=0.2, max_depth=9, n_estimators=100, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=0.2, max_depth=9, n_estimators=900, subsample=0.6; total time=   1.0s
# [CV] END learning_rate=0.2, max_depth=9, n_estimators=900, subsample=0.6; total time=   0.9s
# [CV] END learning_rate=0.2, max_depth=9, n_estimators=900, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.2, max_depth=9, n_estimators=900, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.2, max_depth=9, n_estimators=900, subsample=1.0; total time=   0.6s
# [CV] END learning_rate=0.2, max_depth=9, n_estimators=900, subsample=1.0; total time=   0.5s
# {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 900, 'subsample': 0.8}

# %% [markdown]
# Creamos el modelo y entrenamos. Controlamos el sobreajuste.

# %%
from xgboost import XGBRegressor
xgb = XGBRegressor(learning_rate = 0.01, max_depth = 5, n_estimators = 900, subsample = 0.8) #aplicamos los parametros optimos obtenidos
xgb.fit(X_train, y_train)  #entrenamos el modelo
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=900,
#              n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# Predicción y análisis

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

y_pred = xgb.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
r2_ajustado = 1 - (1 - r2) * (len(y_test) - 1) / (len(y_test) - X_test.shape[1] - 1)

print("MAE: ", mae) #MAE = Error medio en la prediccion
print("MSE:", mse) #MSE = Error cuadratico medio en la prediccion
print("RMSE:", rmse) #RMSE = Raiz del error cuadratico medio en la prediccion
print("R²:", r2) #R^2 = Coeficiente de determinacion
print("R2 ajustado:", r2_ajustado) #R^2 ajustado, si es parecido al normal indica que no hay overfitting ni variables irrelevantes
# Out:
# MAE:  1.3280497331448722
# MSE: 5.266612117162869
# RMSE: 2.2949100455492517
# R²: 0.8709914334087654
# R2 ajustado: 0.8672272577257321

# %% [markdown]
# Obtener variables más importantes en la predicción

# %%
import matplotlib.pyplot as plt
plt.bar(X_train.columns, xgb.feature_importances_)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Comparativa predicción vs realidad

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 7))
plt.scatter(y_test, y_pred, alpha=0.7)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')  #linea de igualdad
plt.xlabel('Valor Real')
plt.ylabel('Valor Predicho')
plt.title('Comparativa predicción vs realidad')
plt.grid()
plt.show()
